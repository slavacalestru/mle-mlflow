# %%
import os
import mlflow

mlflow.set_tracking_uri('file:./mlflow_experiments_store')

experiment_id = mlflow.get_experiment_by_name("Default").experiment_id

with mlflow.start_run(run_name='Default', experiment_id=experiment_id) as run:
    run_id = run.info.run_id
    mlflow.log_metric("test_metric", 0)
    mlflow.log_artifact("test_artifact.txt", "test_artifact")

print(f"Run id launch: {run_id}")
# Out:
# Run id launch: db77c5df7dbd4e9d83f62d0c736f54de

# %%
# !ls mlflow_experiments_store/0/db77c5df7dbd4e9d83f62d0c736f54de/metrics
# Out:
# test_metric

# %%
# !cat mlflow_experiments_store/0/db77c5df7dbd4e9d83f62d0c736f54de/artifacts/test_artifact/test_artifact.txt
# Out:
# test_artifact

# %%
import os
import mlflow

mlflow.set_tracking_uri("http://0.0.0.0:5000")

experiment_id = mlflow.get_experiment_by_name("Default").experiment_id

with mlflow.start_run(run_name='Default', experiment_id=experiment_id) as run:
    run_id = run.info.run_id
    mlflow.log_metric("test_metric", 0)
    mlflow.log_artifact("test_artifact.txt", "test_artifact")

print(f"Run id launch: {run_id}")
# Out:
# Run id launch: 0c2c666f6ef74568a9f3987962df4a53

# %%
assert os.path.exists("mlflow_experiments_store_sqlite")
assert os.path.exists("mydb.sqlite")
